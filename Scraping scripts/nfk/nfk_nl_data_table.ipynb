# %%
import pandas as pd
import hashlib  # Added for generating the content hash
from datetime import datetime  # Added for precise dynamic timestamps

# Current date and time for dataset tracking down to the second
current_date = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

data = {
    "Cancer_type": ["All / General"] * 13,
    "Source_URL": [
        "https://nfk.nl/themas/vroegtijdige-opsporing-van-kanker-in-hoogrisicogroepen",
        "https://nfk.nl/themas/samen-beslissen",
        "https://nfk.nl/themas/samen-beslissen/wat-is-samen-beslissen",
        "https://nfk.nl/onze-doelen/passende-zorg-in-het-juiste-ziekenhuis",
        "https://nfk.nl/onze-doelen/goed-leven-met-kanker",
        "https://nfk.nl/themas/leefstijl-tijdens-en-na-de-behandeling",
        "https://nfk.nl/aangesloten-organisaties",
        "https://nfk.nl/themas/zeldzame-kankers",
        "https://nfk.nl/themas/transparantie",
        "https://nfk.nl/themas/laatste-levensfase",
        "https://nfk.nl/themas/kanker-en-verzekeren",
        "https://nfk.nl/themas/kanker-en-werk",
        "https://nfk.nl/english"
    ],
    "Topic": [
        "Early Detection in High-Risk Groups",
        "Shared Decision Making",
        "Patient Rights as a Cancer Patient",
        "Right to Appropriate / Expert Care",
        "Support - Quality of Life",
        "Support - Lifestyle During and After Treatment",
        "Support - Affiliated Organizations",
        "Rare Cancer Support",
        "Transparency in Healthcare",
        "Final Phase of Life",
        "Cancer and Insurance",
        "Cancer and Work",
        "NFK General Contact"
    ],
    "Question": [
        "What is available regarding early detection for high-risk groups?",
        "What is Shared Decision Making?",
        "What are my rights as a cancer patient?",
        "What is my right to appropriate/expert care?",
        "What support is available for quality of life?",
        "What support is available for lifestyle during and after treatment?",
        "Where can I find peer support for my cancer type?",
        "What support is available for rare cancers?",
        "What does NFK say about transparency in healthcare?",
        "What support is available in the final phase of life?",
        "What support is available regarding cancer and insurance?",
        "What support is available regarding cancer and work?",
        "Who do I contact at NFK for general support?"
    ],
    "General_description": [
        "NFK zet zich in voor een betere vroegtijdige opsporing van kanker bij hoogrisicogroepen, zoals mensen met een erfelijke aanleg of familiegeschiedenis, om de gevolgen van de ziekte zoveel mogelijk te beperken.",
        "Samen Beslissen betekent dat jij en je arts samen beslissen over de behandeling. Medische feiten worden gecombineerd met jouw persoonlijke situatie, wensen en dagelijkse prioriteiten.",
        "Als kankerpatiënt in Nederland heb je belangrijke rechten, waaronder duidelijke informatie, toestemming voor behandeling, inzage in je medisch dossier, een second opinion en deelname aan besluitvorming.",
        "Je hebt het recht om de best mogelijke zorg te krijgen in het meest geschikte gespecialiseerde ziekenhuis, passend bij jouw kankersoort en persoonlijke behoeften.",
        "NFK komt op voor een goede kwaliteit van het dagelijks leven voor mensen die leven met of na kanker en hun naasten, met ondersteuning om deel te nemen aan de samenleving.",
        "Praktische hulpmiddelen van en advies om een gezonde leefstijl te behouden tijdens en na de kankerbehandeling.",
        "NFK is de koepelorganisatie voor 22 kankerpatiëntenorganisaties die gerichte lotgenotenondersteuning en informatie bieden.",
        "NFK ondersteunt betere erkenning, onderzoek en gespecialiseerde zorg voor mensen met zeldzame kankers via aangesloten organisaties.",
        "NFK pleit voor meer transparantie over ziekenhuisresultaten, behandeluitkomsten en zorgdata zodat patiënten betere keuzes kunnen maken.",
        "NFK richt zich op kwaliteit van leven, palliatieve zorg en passende beslissingen in de laatste levensfase.",
        "NFK houdt zich bezig met verzekeringsvraagstukken voor kankerpatiënten, waaronder het 'recht om vergeten te worden' na een bepaalde periode zonder kanker.",
        "NFK biedt belangenbehartiging en informatie over werk, re-integratie en rechten voor mensen die kanker hebben (gehad).",
        "Algemeen contact voor vragen en ondersteuning bij NFK."
    ],
    "Journey_stage": [
        "Diagnosis / Prevention", "Diagnosis / Treatment", "Throughout the Journey",
        "Diagnosis / Treatment", "Aftercare / Recovery", "During and After Treatment",
        "Throughout the Journey", "Throughout the Journey", "Throughout the Journey",
        "Palliative Phase", "Throughout the Journey", "During and After Treatment",
        "General / Support"
    ],
    "Support_type": [
        "Prevention & Early Detection", "Decision Making", "Patient Rights",
        "Care Quality", "Quality of Life", "Lifestyle Support",
        "Peer & Specific Support", "Rare Cancer Support", "Transparency & Information",
        "Palliative & End-of-Life Care", "Insurance & Financial",
        "Work & Reintegration", "Helpline & Contact"
    ],
    "Treatment": [
        "Not treatment-specific", "All types", "General", "Specialized hospital",
        "Not treatment-specific", "During and after", "Not treatment-specific",
        "Specialized for rare", "Not treatment-specific", "Palliative",
        "Not treatment-specific", "During and after", "Not treatment-specific"
    ],
    "Next_step": [
        "Bespreek je familiegeschiedenis of erfelijke risico's met je huisarts en vraag zo nodig doorverwijzing naar klinische genetica.",
        "Bereid je vragen en voorkeuren voor voordat je naar een consult gaat. Gebruik gespreks hulpmiddelen van NFK.",
        "Vraag je arts om duidelijke informatie en vraag inzage in je medisch dossier. Overweeg een second opinion als je twijfelt.",
        "Bespreek met je specialist welk ziekenhuis de beste expertise heeft voor jouw kankersoort en vraag een doorverwijzing aan indien nodig.",
        "Deel je ervaringen via NFK’s ‘Doneer je Ervaring’ en maak contact met ondersteuningsnetwerken.",
        "Gebruik de Leefstijlroer tool op kanker.nl en begin met kleine gezonde leefstijlveranderingen.",
        "Ga naar de pagina met aangesloten organisaties en neem contact op met de groep die past bij jouw kankersoort.",
        "Neem contact op met de patiëntenorganisatie voor jouw zeldzame kankersoort via de lijst van NFK.",
        "Gebruik informatie over ziekenhuisprestaties en uitkomsten bij het kiezen van je behandellocatie.",
        "Bespreek je wensen en voorkeuren voor palliatieve zorg tijdig met je arts en naasten.",
        "Neem contact op met NFK als je problemen hebt met verzekeringen of het recht om vergeten te worden.",
        "Vraag bij je werkgever of arbodienst naar ondersteuning en re-integratiemogelijkheden.",
        "Bel +31 88 00 29 777 of mail secretariaat@nfk.nl voor algemene vragen en begeleiding."
    ],
    "Keywords": [
        "early detection, high risk, hereditary, genetics, prevention",
        "shared decision making, patient involvement",
        "patient rights, second opinion, medical records",
        "expert care, specialized hospital",
        "quality of life, daily living",
        "lifestyle, nutrition, exercise",
        "peer support, patient organizations",
        "rare cancer, specialized care",
        "transparency, hospital performance",
        "palliative care, end of life",
        "insurance, right to be forgotten",
        "work, reintegration, employment",
        "contact, helpline, support"
    ],
    "Date": [current_date] * 13
}

# Generate SHA-256 hashes sequentially based on the data items inside "General_description"
data["Content_hash"] = [hashlib.sha256(text.encode('utf-8')).hexdigest() for text in data["General_description"]]

# Creating a dataframe
df = pd.DataFrame(data)

# Save as a csv file
df.to_csv('nfk_nl_table.csv', index=False, encoding='utf-8')

# saving dataset as xlsx
df.to_excel("nfk_nl_table.xlsx", index=False)


print(df)
print(f"\nDataset Shape: {df.shape[0]} rows x {df.shape[1]} columns")
# Out:
#       Cancer_type                                         Source_URL  \
# 0   All / General  https://nfk.nl/themas/vroegtijdige-opsporing-v...
# 1   All / General              https://nfk.nl/themas/samen-beslissen
# 2   All / General  https://nfk.nl/themas/samen-beslissen/wat-is-s...
# 3   All / General  https://nfk.nl/onze-doelen/passende-zorg-in-he...
# 4   All / General   https://nfk.nl/onze-doelen/goed-leven-met-kanker
# 5   All / General  https://nfk.nl/themas/leefstijl-tijdens-en-na-...
# 6   All / General            https://nfk.nl/aangesloten-organisaties
# 7   All / General             https://nfk.nl/themas/zeldzame-kankers
# 8   All / General                https://nfk.nl/themas/transparantie
# 9   All / General           https://nfk.nl/themas/laatste-levensfase
# 10  All / General         https://nfk.nl/themas/kanker-en-verzekeren
# 11  All / General               https://nfk.nl/themas/kanker-en-werk
# 12  All / General                             https://nfk.nl/english
#
# ...
